# %%
from stat_tests import power
import numpy as np

# %%
import numpy as np

# %%
# %reload_ext autoreload 
# %autoreload 2

# %%
fig, ax = power.plot_sample_size_versus_power(0.2-0.02,stdev=.03*np.sqrt(8))
ax.set_title('Pdyn/PVN (first hour)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 fig, ax = power.plot_sample_size_versus_power(0.2-0.02,stdev=.03*np.sqrt(8))
#       2 ax.set_title('Pdyn/PVN (first hour)')
#
# File ~/projects/stat_tests/stat_tests/power.py:31, in plot_sample_size_versus_power(delta, stdev, significance, power_range, critical_power)
#      29 fig, ax = plt.subplots(1,1)
#      30 ax.plot(powers,n_range,color='k')
# ---> 31 ax.vlines(0.8, ymin = 0, ymax = critical_n, color = 'blue', linestyle = '--', label=rf'critical $n = $ {np.round(n_at_eighty,2)}')
#      32 ax.hlines(critical_n, xmin=0, xmax=critical_power, color='blue',linestyle='--')
#      33 ax.legend()
#
# NameError: name 'n_at_eighty' is not defined

# %%
fig, ax = power.plot_sample_size_versus_power(0.7-0.1,stdev=.1*np.sqrt(5))
ax.set_title('Pdyn/PB (first hour)')
# Out:
# Text(0.5, 1.0, 'Pdyn/PB (first hour)')
