# %%
from stat_tests import power
import numpy as np

# %%
# %reload_ext autoreload 
# %autoreload 2

# %%
fig, ax = power.plot_sample_size_versus_power_t(0.2, 0.02,.03*np.sqrt(8),.03*np.sqrt(8),sample_corr=0.5,two_sided=False,n_range=(1,10))
ax.set_title('Pdyn/PVN (first hour)')
# Out:
# Text(0.5, 1.0, 'Pdyn/PVN (first hour)')

# %%
fig, ax = power.plot_sample_size_versus_power_t(0.7, 0.1,.1*np.sqrt(5),.1*np.sqrt(5),two_sided=False,n_range=(1,5))
ax.set_title('Pdyn/PB (first hour)')
# Out:
# Text(0.5, 1.0, 'Pdyn/PB (first hour)')

# %%
# fig, ax = power.plot_sample_size_versus_power(0.25-0.03,stdev=.05*np.sqrt(5),stdev2=.001*np.sqrt(5))
fig, ax = power.plot_sample_size_versus_power_t(0.25, 0.03,.05*np.sqrt(5),.001*np.sqrt(5),two_sided=False,n_range=(1,5))
ax.set_title('MC4R (ad lib., first hour)')
# Out:
# Text(0.5, 1.0, 'MC4R (ad lib., first hour)')

# %%
# fig, ax = power.plot_sample_size_versus_power(0.45-0.15,stdev=.1*np.sqrt(7),stdev2=.075*np.sqrt(8))
fig, ax = power.plot_sample_size_versus_power_t(0.45, 0.15,.1*np.sqrt(7),.075*np.sqrt(8),two_sided=False,n_range=(1,15))
# fig, ax = power.plot_sample_size_versus_power(0.45-0.15,stdev=.1*np.sqrt(7))
ax.set_title('Glp1R Arcuate (first hour)')
# Out:
# Text(0.5, 1.0, 'Glp1R Arcuate (first hour)')

# %%
# fig, ax = power.plot_sample_size_versus_power(0.45-0.2,stdev=.01*np.sqrt(7))
fig, ax = power.plot_sample_size_versus_power_t(0.45, 0.2,.01*np.sqrt(7),.01*np.sqrt(7),two_sided=False,n_range=(1,5))
ax.set_title('Glp1R PVN (first hour)')
# Out:
# Text(0.5, 1.0, 'Glp1R PVN (first hour)')

# %%
#GIP
sal = [0.71,0.68,0.53,0.44]
cno = [0,0.1,0.05,0.4]
np.corrcoef(sal,cno,)
# Out:
# array([[ 1.      , -0.786991],
#        [-0.786991,  1.      ]])

# %%
np.std(sal)
# Out:
# 0.110227038425243

# %%
fig, ax = power.plot_sample_size_versus_power_t(np.mean(sal), np.mean(cno),.01*np.std(sal),np.std(cno),sample_corr=-0.79,two_sided=False,n_range=(1,5))
ax.set_title('GIP arcuate')
# Out:
# Text(0.5, 1.0, 'GIP arcuate')
